# %%
import util as ut
import face_recognition as fr
from config import ROOT_DIR
import os

# %%
dirname = os.path.join(ROOT_DIR, "datasets")
mtx = ut.image_to_matrix(dirname)
ut.show_image_plt(fr.average_face(mtx).reshape(256,256))
